# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os

from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models are crucial in today's technological landscape, and their importance can be understood from several perspectives:
#
# 1. **Efficient Processing**: Fast language models enable rapid text processing, allowing for quicker response times and improved user experiences. This is particularly important in applications such as virtual assistants, chatbots, and language translation software, where speed and accuracy are essential.
#
# 2. **Real-time Applications**: Fast language models are essential for real-time applications like speech recognition, sentiment analysis, and text summarization. These models can process and understand human language in real-time, enabling swift decision-making and action.
#
# 3. **Large-Scale Data Processing**: Fast language models can handle massive amounts of data, making them suitable for large-scale natural language processing (NLP) tasks, such as data mining, information retrieval, and text analytics. This facilitates the extraction of valuable insights from vast amounts of unstructured text data.
#
# 4. **Improved Accuracy**: Faster language models can process more data in less time, which can lead to improved accuracy in tasks like language translation, sentiment analysis, and question answering. This, in turn, enhances the overall performance of NLP systems.
#
# 5. **Enhanced User Experience**: Fast language models can significantly enhance user experience in various applications, such as:
# 	* **Virtual assistants**: Quick response times enable seamless interactions with virtual assistants like Siri, Alexa, or Google Assistant.
# 	* **Language translation**: Fast language models facilitate real-time translation, breaking language barriers and enabling global communication.
# 	* **Text summarization**: Rapid text summarization helps users quickly grasp the essence of lengthy documents or articles.
#
# 6. **Edge Computing**: Fast language models are particularly important for edge computing, where data processing occurs on-device or at the edge of the network. This reduces latency, enhances real-time processing, and conserves bandwidth.
#
# 7. **Research and Development**: Fast language models accelerate research and development in NLP, enabling scientists to explore new ideas, test hypotheses, and refine models more quickly. This, in turn, drives innovation and advancements in the field.
#
# 8. **Industry Applications**: Fast language models have numerous industry applications, including:
# 	* **Customer service**: Chatbots and virtual assistants powered by fast language models provide efficient customer support.
# 	* **Healthcare**: Fast language models can quickly analyze medical texts, helping healthcare professionals diagnose diseases and develop treatment plans.
# 	* **Finance**: Fast language models can rapidly process financial documents, facilitating tasks like risk assessment and portfolio management.
#
# In summary, fast language models are vital for efficient processing, real-time applications, large-scale data processing, improved accuracy, enhanced user experience, edge computing, research and development, and various industry applications. As NLP continues to evolve, the importance of fast language models will only continue to grow.

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from huggingface_hub import InferenceClient
from google import genai
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

# openai_api_key = os.getenv('OPENAI_API_KEY')
# anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
# deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
openrouter_base_url = os.getenv('OPENROUTER_BASE_URL')

hf_api_key = os.getenv('HF_API_KEY')


# if openai_api_key:
#     print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
# else:
#     print("OpenAI API Key not set")
    
# if anthropic_api_key:
#     print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
# else:
#     print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

# if deepseek_api_key:
#     print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set (and this is optional)")

if openrouter_base_url:
    print(f"OpenRouter Base URL exists and begins {openrouter_base_url[:8]}")

if hf_api_key:
    print(f"Hugging Face API Key exists and begins {hf_api_key[:8]}")
else:
    print("Hugging Face API Key not set (and this is optional)")
# Out:
# Google API Key exists and begins AI
# Groq API Key exists and begins gsk_
# OpenRouter API Key exists and begins sk-or-v1
# OpenRouter Base URL exists and begins https://
# Hugging Face API Key exists and begins hf_zVAMa

# %%
client = InferenceClient(
    model="mistralai/Mistral-7B-Instruct-v0.2",
    token=hf_api_key
)

response = client.chat_completion(
    messages=[
        {"role": "user", "content": "Explain Python decorators simply"}
    ],
    max_tokens=200
)

print(response.choices[0].message["content"])
# Out:
#  A decorator in Python is a design pattern that allows you to add additional functionality to an existing function or method, without modifying its source code directly. Decorators are implemented as special type of functions in Python, which take the function or method as an argument, and return a new function or method as a result.
#
# Here's a simple example to illustrate how decorators work:
#
# ```python
# # A simple decorator that logs the function calls
# def logger(func):
#     def wrapper(*args, **kwargs):
#         print(f"Calling function {func.__name__} with arguments {args} and keywords {kwargs}")
#         result = func(*args, **kwargs)
#         print(f"Function {func.__name__} returned {result}")
#         return result
#     return wrapper
#
# # A simple function that adds two numbers
# @logger
# def add(x, y):
#     return x +

# %%
client = OpenAI(
    api_key=openrouter_api_key,
    base_url=openrouter_base_url
)

response = client.chat.completions.create(
    model="meta-llama/llama-3.1-8b-instruct",
    messages=[
        {"role": "user", "content": "Explain Python decorators simply"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Python decorators! They can seem intimidating at first, but trust me, they're actually quite simple once you grasp the concept.
#
# **What is a decorator?**
#
# In simple terms, a decorator is a function that takes another function as an argument and returns a new function that "wraps" the original function. Think of it like a gift wrapper: you take a function (the gift), wrap it with a new function (the wrapper), and return the wrapped function.
#
# **Basic syntax**
#
# Here's the basic syntax:
# ```python
# @decorator_name
# def original_function():
#     pass
# ```
# This is equivalent to:
# ```python
# def original_function():
#     pass
# original_function = decorator_name(original_function)
# ```
# **How it works**
#
# Here's a step-by-step breakdown:
#
# 1. The `@decorator_name` syntax is just a shortcut for the second example above.
# 2. When Python sees the `@decorator_name` syntax, it replaces `original_function` with the result of calling `decorator_name(original_function)`.
# 3. The `decorator_name` function takes `original_function` as an argument.
# 4. The `decorator_name` function returns a new function, which "wraps" the original function.
# 5. The new function is assigned to `original_function`.
#
# **Example**
#
# Let's say we want to create a decorator that logs the execution time of a function:
# ```python
# import time
# from functools import wraps
#
# def timer_decorator(func):
#     @wraps(func)
#     def wrapper(*args, **kwargs):
#         start_time = time.time()
#         result = func(*args, **kwargs)
#         end_time = time.time()
#         print(f"Function '{func.__name__}' took {end_time - start_time} seconds to execute.")
#         return result
#     return wrapper
#
# @timer_decorator
# def my_function():
#     time.sleep(2)
#     print("Hello, world!")
#
# my_function()
# ```
# In this example:
#
# 1. The `timer_decorator` function takes `my_function` as an argument.
# 2. The `timer_decorator` function returns a new function (`wrapper`) that wraps `my_function`.
# 3. When we call `my_function()`, Python executes the `wrapper` function, which:
# 	* Logs the execution time of `my_function`.
# 	* Calls `my_function` with the original arguments (`time.sleep(2)` and `print("Hello, world!")`).
# 	* Returns the result of `my_function`.
#
# **Common use cases**
#
# Decorators are useful for:
#
# 1. Logging: like the `timer_decorator` example above.
# 2. Authentication: e.g., checking if a user is logged in before allowing access to a function.
# 3. Caching: e.g., storing the result of a function so it doesn't need to be recalculated every time.
# 4. Input validation: e.g., checking if a function's arguments are valid before executing it.
#
# I hope this explanation helped simplify decorators for you!

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages[0]['content']
# Out:
# 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'

# %%
# openai = OpenAI()
# response = openai.chat.completions.create(
#     model="gpt-5-mini",
#     messages=messages,
# )
# question = response.choices[0].message.content
# print(question)

# Try the versioned string if the alias fails

google = genai.Client()

question = google.models.generate_content(
    model="gemini-2.5-flash-lite", 
    contents=messages[0]['content']
).text

print(question)
# Out:
# Given a meticulously crafted, fictional historical account where a pivotal battle was *not* won by the conventionally understood victor due to a series of cascading improbable events stemming from a single, seemingly minor, miscommunication, how would you, as an LLM, best identify and articulate the causal chain of this divergence from historical probability, and then construct a plausible, well-reasoned counterfactual narrative that explains the *actual* outcome based on your identified causal links, while also acknowledging the inherent limitations in definitively establishing such a chain given the fictional nature of the premise?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Given a meticulously crafted, fictional historical account where a pivotal battle was *not* won by the conventionally understood victor due to a series of cascading improbable events stemming from a single, seemingly minor, miscommunication, how would you, as an LLM, best identify and articulate the causal chain of this divergence from historical probability, and then construct a plausible, well-reasoned counterfactual narrative that explains the *actual* outcome based on your identified causal links, while also acknowledging the inherent limitations in definitively establishing such a chain given the fictional nature of the premise?'}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

# model_name = "gpt-5-nano"

# response = openai.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)


# Using the Hugging Face Interface using the mistralai model

model_name = "mistralai/Mistral-7B-Instruct-v0.2"

client = InferenceClient(
    model=model_name,
    token=hf_api_key
)

response = client.chat_completion(
    messages=messages
)

answer = response.choices[0].message["content"]

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
#  To identify and articulate the causal chain of the divergence from historical probability in a fictional historical account where a pivotal battle was not won by the conventionally understood victor due to a single, seemingly minor, miscommunication, I would follow these steps:
#
# 1. Identify the miscommunication: The first step would be to identify the exact miscommunication that set off the chain of improbable events. This could involve analyzing the dialogue or actions of the key figures involved in the narrative leading up to the battle, and examining the potential meaning and intent behind their words or actions.
#
# 2. Trace the immediate consequences: Once the miscommunication has been identified, the next step would be to trace the immediate consequences of that miscommunication. This could involve analyzing the actions of the opposing side, as well as their reactions to the perceived advantage gained due to the miscommunication.
#
# 3. Consider the snowball effect: It is important to consider the potential snowball effect of the miscommunication, as the consequences can often compound over time, leading to even more significant and unforeseen outcomes. For example, a misunderstanding between two commanders could lead to a misdeployment of troops, which in turn could lead to a break in the enemy lines, which could lead to a panic among the enemy ranks, and so on.
#
# 4. Consider the counterfactual: To construct a plausible, well-reasoned counterfactual narrative, it is essential to consider what would have happened if the miscommunication had not occurred. This could involve examining the strategic situation before the battle, as well as the motivations, capabilities, and dispositions of the key actors involved. It may also be necessary to make some assumptions about how events would have unfolded differently if the miscommunication had not taken place.
#
# 5. Acknowledge the inherent limitations: It is important to acknowledge the inherent limitations in definitively establishing a causal chain in a fictional historical account. While analysis and reasoning can help shed light on the possible consequences of the miscommunication, it is ultimately impossible to know for sure how events would have unfolded if history had taken a different course. Therefore, any counterfactual narrative should be considered as a plausible, but not definitive, alternative to the conventional historical account.
#
# 6. Use historical context: To make the counterfactual narrative more compelling, it is essential to ground it in historical context. This could involve using real historical facts and events as a basis for the narrative and extrapolating from them in a plausible way. For example, if the miscommunication occurred during the Battle of Waterloo, it could be useful to consider the strategic situation on the ground, the dispositions of the armies, and the motivations of the key commanders involved.
#
# 7. Use logical reasoning: To craft a convincing counterfactual narrative, it is important to use logical reasoning to explain why and how the miscommunication led to the divergence from historical probability. This could involve examining the potential motivations and rationales of the key actors involved, as well as the strategic and tactical implications of their actions and reactions. Logical reasoning can help to establish a coherent and plausible narrative that challenges the conventional historical account.
#
# 8. Consider the ripple effects: To create a fully developed counterfactual narrative, it is important to consider the ripple effects of the miscommunication and the potential ways in which the divergence from historical probability could have cascaded through history. For example, if a battle was not won by the conventionally understood victor, the aftermath could have significant consequences for the course of history. It may be necessary to consider the potential political, social, and economic implications of the alternative outcome.
#
# 9. Use evidence and analysis: To strengthen the counterfactual narrative, it is important to use evidence and analysis to support the alternative historical outcome. This could involve examining primary sources, secondary sources, and other historical data to demonstrate how the miscommunication and its consequences fit within the broader context of history. The use of evidence and analysis can help to create a more persuasive and credible counterfactual narrative.
#
# 10. Be creative but grounded: Finally, it is important to be creative but grounded when constructing a counterfactual narrative based on a fictional historical account. By using historical context, logical reasoning, and evidence to support the alternative outcome, it is possible to create a plausible and compelling narrative that challenges the conventional historical account while remaining faithful to the underlying facts and themes of history. Ultimately, the goal is to explore the potential consequences of small events in history in a thought-provoking and engaging way, while remaining mindful of the inherent limitations of counterfactual analysis in a fictional context.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

# model_name = "claude-sonnet-4-5"

# claude = Anthropic()
# response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
# answer = response.content[0].text

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

# Using the meta-llama3.1 model with openrouter

client = OpenAI(
    api_key=openrouter_api_key,
    base_url=openrouter_base_url
)

model_name = "meta-llama/llama-3.1-8b-instruct"

response = client.chat.completions.create(
    model=model_name,
    messages=messages
)

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
#  To identify and articulate the causal chain of the divergence from historical probability in a fictional historical account where a pivotal battle was not won by the conventionally understood victor due to a single, seemingly minor, miscommunication, I would follow these steps:
#
# 1. Identify the miscommunication: The first step would be to identify the exact miscommunication that set off the chain of improbable events. This could involve analyzing the dialogue or actions of the key figures involved in the narrative leading up to the battle, and examining the potential meaning and intent behind their words or actions.
#
# 2. Trace the immediate consequences: Once the miscommunication has been identified, the next step would be to trace the immediate consequences of that miscommunication. This could involve analyzing the actions of the opposing side, as well as their reactions to the perceived advantage gained due to the miscommunication.
#
# 3. Consider the snowball effect: It is important to consider the potential snowball effect of the miscommunication, as the consequences can often compound over time, leading to even more significant and unforeseen outcomes. For example, a misunderstanding between two commanders could lead to a misdeployment of troops, which in turn could lead to a break in the enemy lines, which could lead to a panic among the enemy ranks, and so on.
#
# 4. Consider the counterfactual: To construct a plausible, well-reasoned counterfactual narrative, it is essential to consider what would have happened if the miscommunication had not occurred. This could involve examining the strategic situation before the battle, as well as the motivations, capabilities, and dispositions of the key actors involved. It may also be necessary to make some assumptions about how events would have unfolded differently if the miscommunication had not taken place.
#
# 5. Acknowledge the inherent limitations: It is important to acknowledge the inherent limitations in definitively establishing a causal chain in a fictional historical account. While analysis and reasoning can help shed light on the possible consequences of the miscommunication, it is ultimately impossible to know for sure how events would have unfolded if history had taken a different course. Therefore, any counterfactual narrative should be considered as a plausible, but not definitive, alternative to the conventional historical account.
#
# 6. Use historical context: To make the counterfactual narrative more compelling, it is essential to ground it in historical context. This could involve using real historical facts and events as a basis for the narrative and extrapolating from them in a plausible way. For example, if the miscommunication occurred during the Battle of Waterloo, it could be useful to consider the strategic situation on the ground, the dispositions of the armies, and the motivations of the key commanders involved.
#
# 7. Use logical reasoning: To craft a convincing counterfactual narrative, it is important to use logical reasoning to explain why and how the miscommunication led to the divergence from historical probability. This could involve examining the potential motivations and rationales of the key actors involved, as well as the strategic and tactical implications of their actions and reactions. Logical reasoning can help to establish a coherent and plausible narrative that challenges the conventional historical account.
#
# 8. Consider the ripple effects: To create a fully developed counterfactual narrative, it is important to consider the ripple effects of the miscommunication and the potential ways in which the divergence from historical probability could have cascaded through history. For example, if a battle was not won by the conventionally understood victor, the aftermath could have significant consequences for the course of history. It may be necessary to consider the potential political, social, and economic implications of the alternative outcome.
#
# 9. Use evidence and analysis: To strengthen the counterfactual narrative, it is important to use evidence and analysis to support the alternative historical outcome. This could involve examining primary sources, secondary sources, and other historical data to demonstrate how the miscommunication and its consequences fit within the broader context of history. The use of evidence and analysis can help to create a more persuasive and credible counterfactual narrative.
#
# 10. Be creative but grounded: Finally, it is important to be creative but grounded when constructing a counterfactual narrative based on a fictional historical account. By using historical context, logical reasoning, and evidence to support the alternative outcome, it is possible to create a plausible and compelling narrative that challenges the conventional historical account while remaining faithful to the underlying facts and themes of history. Ultimately, the goal is to explore the potential consequences of small events in history in a thought-provoking and engaging way, while remaining mindful of the inherent limitations of counterfactual analysis in a fictional context.

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# This is an excellent challenge that delves into the core of counterfactual history and causal analysis, even within a fictional framework. As an LLM, my approach would involve a structured process of hypothesizing the initial conditions, tracing the logical (and improbable) consequences, and then reconstructing the "actual" timeline.
#
# Let's establish a fictional scenario first, to provide the ground for our analysis:
#
# ---
#
# ### **Fictional Scenario: The Battle of the Sunder Pass**
#
# **Conventional Understanding:** The Battle of the Sunder Pass (circa 17th century analogue) was historically understood to be a decisive victory for the **Coalition of Free Cities**, led by the brilliant tactician Lord-General Atherton. His masterful encirclement maneuver, combining a frontal assault with a hidden flank attack, was supposed to crush the entrenched **Imperial Hegemony** forces, led by the steadfast but less imaginative Marshal Kaelen. This victory was meant to open the way to the Imperial capital and hasten the end of a long war.
#
# **The Divergence (The Actual Outcome in this Fictional Account):** Contrary to the conventional understanding, the Coalition *lost* the Battle of the Sunder Pass catastrophically. Lord-General Atherton's forces were not only repulsed but suffered a devastating rout, allowing Marshal Kaelen to consolidate his position and prolong the war for several more years.
#
# ---
#
# ### **1. Identifying and Articulating the Causal Chain of Divergence**
#
# The prompt states this divergence stems from a "single, seemingly minor, miscommunication" leading to "a series of cascading improbable events."
#
# **The Single, Seemingly Minor Miscommunication:**
#
# *   **The Message:** Lord-General Atherton's battle plan relied heavily on a synchronized pincer movement. His main infantry force would engage Marshal Kaelen's entrenched center, while a crucial cavalry division, commanded by General Valerius, would execute a wide flanking maneuver through the treacherous "Whispering Glade" to strike the Imperial rear.
# *   **The Critical Detail:** The precise time for Valerius's flank attack was paramount. Atherton's dispatch specified: "Valerius to initiate rear assault at *0600 hours*, coinciding with our main push. *Maintain radio silence until contact*."
# *   **The Miscommunication:** The courier carrying this vital dispatch to General Valerius was a junior officer, newly assigned and overly zealous. During the arduous night ride through rough terrain, he lost the top page of the two-page order. The second page, which detailed the *route* through the Glade, began with the instruction "Proceed *swiftly and silently until dawn*," followed by tactical details. The crucial "0600 hours" was on the missing first page. The young officer, having been ordered to deliver "the plan," presented only the surviving page, assuming it was complete. General Valerius, receiving only the second page, interpreted "Proceed swiftly and silently until dawn" as the *signal to begin his main advance* at first light, roughly 0500 hours, and *not* just a pre-movement instruction for the advance to its staging point. He also interpreted "Maintain radio silence until contact" as absolute, rather than just during the approach.
#
# **The Cascading Improbable Events (and their increasingly detrimental effects):**
#
# 1.  **Event 1: Premature Flank Engagement (Direct Consequence of Miscommunication)**
#     *   **Link:** General Valerius, interpreting "until dawn" as the attack command, launched his cavalry attack an hour earlier than intended (around 0500 hours instead of 0600 hours).
#     *   **Impact:** This meant Valerius's cavalry hit the Imperial rear while Atherton's main frontal assault was still maneuvering into position, well before its coordinated 0600 push. The Imperial rear, though caught off guard, faced a comparatively smaller, isolated force.
#
# 2.  **Event 2: Imperial Counter-Response and Early Warning (First Improbable Link)**
#     *   **Link:** Due to Valerius's premature, isolated attack, the Imperial forces in the rear were able to react more effectively. Marshal Kaelen, having anticipated a flanking maneuver *eventually*, had positioned a small, but elite, unit of skirmishers with trained signal hawks.
#     *   **Impact:** One of these hawks, released upon the first sounds of Valerius's attack, flew *directly* over Atherton's still-forming main assault lines, a highly improbable flight path due to the general direction of the wind and typical hawk behavior. This early warning, combined with its unusual trajectory, was spotted by Kaelen's forward scouts, alerting Kaelen *an hour earlier* than expected to the full scope of Atherton's planned two-pronged attack.
#
# 3.  **Event 3: Misinterpretation and Defensive Repositioning (Second Improbable Link)**
#     *   **Link:** Marshal Kaelen, receiving the hawk signal and confirming reports of Valerius's early, isolated attack on his rear, made a crucial (and incorrect) assumption: he believed Valerius's early attack was a desperate, premature feint designed to mask a *different*, larger flank attack, or that Atherton's main force had simply miscalculated the timing.
#     *   **Impact:** Instead of diverting significant reserves to the rear (which would have been the correct counter to the *intended* plan), Kaelen reinforced his own central lines and *shifted reserves to cover what he perceived as the unthreatened flank*, believing Atherton's main thrust would come from a different direction than the one Valerius had hit. He also instructed his rear guard to simply hold Valerius, not defeat him, saving strength for the perceived main threat. This was a direct misinterpretation born from Valerius's ill-timed assault and the hawk's unusual flight.
#
# 4.  **Event 4: Atmospheric Anomaly and Communication Breakdown (Third Improbable Link)**
#     *   **Link:** Precisely at 0600 hours, as Atherton's main assault began its coordinated push, an unexpectedly thick and localized fog bank rolled into the Sunder Pass. This "Sunder Fog" was extremely rare for that time of year and location.
#     *   **Impact:** The fog severely hampered visibility and acoustics. Valerius, in the rear, was unable to discern the sounds of Atherton's main assault due to the fog and the ongoing skirmish with the Imperial rear guard. He continued to fight an isolated battle. Critically, Atherton's main force, now advancing into the fog, was unable to accurately gauge enemy positions or see their own flanks, believing Valerius would soon hit the rear.
#
# 5.  **Event 5: The "Phantom Flank" and Allied Disarray (Culmination of Improbability)**
#     *   **Link:** Due to Kaelen's repositioning (Event 3) and the fog (Event 4), Atherton's main assault found the Imperial center far stronger than anticipated. Simultaneously, because Valerius was still isolated and fighting a holding action (Event 1, compounded by Event 4), his expected pressure on the Imperial rear never materialized in time. As the Coalition pressed into the fog, Kaelen's strategically repositioned reserves (from Event 3) emerged from the fog on the *actual* (uncovered) flank of Atherton's main force.
#     *   **Impact:** Atherton's forces, expecting to crush a weakened center with a flank attack from Valerius, instead found themselves bogged down in a reinforced Imperial center and then unexpectedly flanked by Kaelen's fresh troops appearing almost magically from the fog. This utterly shattered Coalition morale and command structure. Valerius, finally breaking through the Imperial rear, emerged hours later to find only the scattered remnants of Atherton's routed army.
#
# ---
#
# ### **2. Constructing a Plausible, Well-Reasoned Counterfactual Narrative**
#
# The Battle of the Sunder Pass, conventionally lauded as a strategic masterpiece for Lord-General Atherton, was, in truth, a devastating defeat that prolonged the war for years. The cause, ironically, lay not in grand strategic error, but in a series of unfortunate events triggered by a single, seemingly trivial miscommunication regarding a courier's dispatch.
#
# Lord-General Atherton's plan was elegant: a simultaneous, crushing blow. His main infantry, under his direct command, would pin Marshal Kaelen's forces in the Sunder Pass, while General Valerius's elite cavalry, having executed a daring night march through the Whispering Glade, would assault the Imperial rear at precisely **0600 hours**. This coordinated strike was designed to break Kaelen's lines and secure victory.
#
# However, fate intervened in the form of a lost page from a crucial dispatch. A junior officer, delivering Valerius's orders, presented only the second page, which instructed "Proceed swiftly and silently until dawn." Interpreting this as the command to attack, Valerius, zealous and eager, launched his cavalry assault at **0500 hours**, an hour ahead of schedule.
#
# This premature strike, while initially successful in catching the Imperial rear guard by surprise, lacked the essential coordination with Atherton's main force. Valerius's cavalry became bogged down in a skirmish, preventing them from achieving the decisive breakthrough at the critical moment.
#
# More consequentially, the early engagement had an unforeseen ripple effect. A small unit of Imperial skirmishers, equipped with trained signal hawks, was deployed in the rear. By an improbable twist of fate, one of these hawks, startled by Valerius's premature charge, soared aloft on an unusual thermal current, passing directly over Atherton's still-forming main lines. Marshal Kaelen's forward scouts, alerted by the hawk's unprecedented flight path and receiving garbled reports of an early, isolated attack on his rear, drew a critical, and ultimately victorious, conclusion: Atherton was attempting a clever feint, hoping to draw reserves to his rear while planning a *different*, larger flanking maneuver from another direction.
#
# Acting on this erroneous belief, Kaelen shrewdly reinforced his central positions, not to defend against Valerius, but to withstand Atherton's anticipated frontal assault, while shifting critical reserves to cover what he now perceived as the *actual* vulnerable flank – the one Atherton was *not* currently attacking.
#
# Then, as if the Fates themselves conspired, a thick, localized fog, highly unusual for the season, rolled into the Sunder Pass at precisely 0600 hours – the moment Atherton's main assault was meant to commence. This "Sunder Fog" turned the battlefield into a confusing labyrinth. Atherton's forces, expecting Valerius to be hitting the Imperial rear with full force, advanced into a much stronger and better-prepared center than anticipated. Communications were severed by the fog, and Valerius, still engaged in the rear, was unaware of the main push's desperate struggle.
#
# The climax arrived when Kaelen's repositioned reserves, previously moved to counter a phantom flank attack, emerged from the dense fog on Atherton's *actual*, now exposed flank. This sudden, unexpected appearance of fresh Imperial troops, seemingly out of nowhere, shattered the morale of the Coalition infantry. Already struggling against a reinforced center, and with no sign of Valerius's expected support from the rear, Atherton's lines buckled. What began as a strategic withdrawal quickly devolved into a full-scale rout.
#
# General Valerius, finally breaking through the battered Imperial rear guard hours later, found not the coordinated victory he expected, but the chaotic remnants of a defeated army retreating in disarray. Marshal Kaelen, by a remarkable series of improbable interpretations and atmospheric luck stemming from a single, overlooked detail in a dispatch, had turned certain defeat into a decisive victory, altering the course of the war.
#
# ---
#
# ### **3. Acknowledging Inherent Limitations**
#
# Even within this meticulously crafted fictional premise, definitively establishing such a causal chain, particularly one reliant on "cascading improbable events," presents significant limitations:
#
# 1.  **The "Butterfly Effect" Paradox:** While the premise *demands* a single minor cause, real-world historical analysis often struggles to isolate *one* singular trigger for major events. Outcomes are typically the result of a confluence of factors. In fiction, we *design* for a single cause, but even then, the cascade relies on a high degree of specificity.
# 2.  **Plausibility vs. Probability:** The chain of events, especially the "improbable" ones (e.g., the signal hawk's precise flight path, the unusual fog, Kaelen's specific misinterpretation leading to a *beneficial* countermove), is constructed for narrative effect and plausibility within the fictional rules. In a truly probabilistic historical analysis, the odds of *all* these specific factors aligning would be astronomically low. We are explaining *how* it happened given the premise, not *why it was likely* to happen.
# 3.  **Human Agency and Interpretation:** The miscommunication relies on human error and interpretation (the courier's assumption, Valerius's reading of the order, Kaelen's tactical conclusion). While plausible, different individuals might have reacted differently, or sought clarification. The "minor" miscommunication requires very specific individual responses to trigger the large-scale cascade.
# 4.  **Narrative Cohesion vs. Historical Complexity:** In constructing this counterfactual, I've prioritized a clear, flowing narrative that demonstrates the requested causal links. Real historical analysis involves sifting through fragmented evidence, conflicting accounts, and a much wider array of potential contributing factors, many of which might remain unknown or unknowable.
# 5.  **Fictional Construct:** Ultimately, this entire exercise is based on a fictional premise. The "truth" of the original historical account, the conventional understanding, and the divergent "actual" outcome are all constructs. My role is to logically connect the provided fictional elements, not to uncover an objective historical reality. The "definitive establishment" is limited by the very nature of the narrative's hypothetical constraints.
#
# In essence, while I can *construct* a plausible and well-reasoned causal chain and narrative that adheres to the prompt's rules, it's a creative act of storytelling and logical deduction within a defined fictional world, rather than a definitive historical analysis of a real event.

# %%
messages[0]['content']
# Out:
# 'Given a meticulously crafted, fictional historical account where a pivotal battle was *not* won by the conventionally understood victor due to a series of cascading improbable events stemming from a single, seemingly minor, miscommunication, how would you, as an LLM, best identify and articulate the causal chain of this divergence from historical probability, and then construct a plausible, well-reasoned counterfactual narrative that explains the *actual* outcome based on your identified causal links, while also acknowledging the inherent limitations in definitively establishing such a chain given the fictional nature of the premise?'

# %%
# deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
# model_name = "deepseek-chat"

# response = deepseek.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

google = genai.Client()

model_name = "gemini-2.5-flash-lite"

answer = google.models.generate_content(
    model=model_name, 
    contents=messages[0]['content']
).text

print(question)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a step‑by‑step guide that shows **how** an LLM can (1) pull the divergent thread out of a fictional “what‑if” scenario, (2) map the chain of cause‑and‑effect that turned the battle on its head, (3) turn that map into a coherent counter‑factual narrative, and (4) keep the analysis honest about the speculative nature of the exercise.
#
# ---
#
# ## 1.  Unpacking the Premise – Pinpoint the “Single Mis‑communication”
#
# | **What to look for** | **Why it matters** | **Typical evidence (fictional or real)** |
# |----------------------|--------------------|------------------------------------------|
# | **Who said what, to whom, and when?** | A mis‑communication is only a *mis‑communication* if the message reached the wrong audience or arrived at the wrong time. | A messenger’s delayed report, a mis‑read signal flag, an ambiguous written order. |
# | **The medium of transmission** | Different media have distinct failure modes (e.g., smoke signals vs. written dispatch). | Smoke mis‑read as “retreat” instead of “hold”. |
# | **Contextual pressure** | High‑stress situations (night, rain, chaos) raise the probability of a slip. | Night‑time crossing of a river while under artillery fire. |
# | **Immediate decision made on the basis of the error** | This decision is the first node in the causal chain. | The commander decides to abandon a hilltop position. |
#
# **Action for the LLM:**
# 1. **Extract the sentence(s)** that describe the mis‑communication.
# 2. **Tag** the actors (sender, receiver), the *message* (content), and the *channel* (courier, signal, etc.).
# 3. **Timestamp** the event relative to the battle timeline (e.g., “30 min before the main assault”).
#
# *Example (fictional):*
# > “At 04:12 am, Lieutenant Marin’s dispatch, intended to order the left‑flank artillery to fire a preparatory barrage, was intercepted by a stray scout and delivered to Captain Varga, who interpreted it as a command to withdraw the batteries.”
#
# - **Sender:** Lieutenant Marin
# - **Receiver (intended):** Left‑flank artillery commander
# - **Receiver (actual):** Captain Varga (infantry)
# - **Message:** “Fire preparatory barrage” → mis‑read as “withdraw”
#
# ---
#
# ## 2.  Building the Causal Chain – From One Mistake to a Battle‑wide Collapse
#
# ### 2.1  Diagrammatic Thinking (Narrative‑Friendly)
#
# ```
# Mis‑communication
#       ↓
# Immediate tactical error (artillery does not fire)
#       ↓
# Enemy retains momentum (no suppression)
#       ↓
# Infantry flank is exposed → higher casualties
#       ↓
# Commanding general loses confidence → orders premature retreat
#       ↓
# Morale collapses → units begin to rout
#       ↓
# Enemy exploits gap → decisive victory
# ```
#
# ### 2.2  Assessing “Improbability”
#
# | **Link** | **Historical baseline probability** | **Improbability factor** (qualitative) | **Why the fiction makes it plausible** |
# |----------|------------------------------------|----------------------------------------|----------------------------------------|
# | Artillery fails to fire because of mis‑read order | ~5 % (messenger loss, mis‑read orders were rare) | **High** (requires both interception and misinterpretation) | The story adds a *stray scout* in a foggy night, raising the odds. |
# | Enemy retains momentum without artillery suppression | ~30 % (depends on terrain, enemy discipline) | **Medium** | The hill‑top gave the enemy a line‑of‑sight advantage; losing barrage mattered. |
# | Premature retreat ordered by general | ~10 % (generals rarely retreat early unless convinced) | **Medium‑High** | General is portrayed as already nervous after prior setbacks. |
# | Morale collapse → rout | ~15 % (depends on cohesion, leadership) | **Medium** | The army had a mixed composition of conscripts and veterans; the loss of artillery was a psychological shock. |
#
# **LLM tip:** Use *qualitative* probability language (“unlikely but not impossible”) rather than precise numbers unless the source material supplies them. The goal is to show why the chain, while improbable, is *coherent*.
#
# ### 2.3  Causal‑Link Narrative Templates
#
# | **Link** | **Template** |
# |----------|--------------|
# | Mis‑communication → Tactical error | “Because the message *X* was delivered to *Y* instead of *Z*, the intended action *A* was never executed, leaving the battlefield *B* vulnerable.” |
# | Tactical error → Operational consequence | “The absence of *A* allowed the opposing force to maintain *C*, which in turn forced our troops on *D* to react in a *E* manner.” |
# | Operational consequence → Strategic outcome | “The resulting *E* undermined the commander’s confidence, prompting a *F* order that cascaded into a full‑scale retreat.” |
#
# ---
#
# ## 3.  Crafting the Counter‑factual Narrative
#
# ### 3.1  Structure Overview
#
# | **Section** | **Purpose** | **Key Elements** |
# |-------------|-------------|------------------|
# | **A. Point of Divergence (PoD)** | State the precise moment where history departs. | “At 04:12 am… the dispatch reached the correct artillery commander.” |
# | **B. Immediate Ripple** | Show the first direct effect of the corrected event. | “The left‑flank batteries opened fire on schedule, softening the enemy’s advance.” |
# | **C. Mid‑Battle Cascade** | Trace how the initial correction reshapes subsequent decisions. | “With the barrage successful, the infantry held the hill, the general retained confidence, and no retreat order was issued.” |
# | **D. End‑State Outcome** | Summarize the final, divergent result of the battle (and perhaps its downstream historical impact). | “The victorious side secured the valley, altering the political balance for the next decade.” |
# | **E. Probability Reflection** | Briefly discuss why this alternate chain is plausible (or less improbable) given the corrected PoD. | “Because messenger reliability was historically >90 %, the corrected transmission would have been the most likely outcome.” |
# | **F. Limitations Disclaimer** | Acknowledge the speculative nature. | “This reconstruction assumes all other variables remained constant, which is a simplification.” |
#
# ### 3.2  Sample Counter‑factual (based on the fictional mis‑communication above)
#
# > **A. Point of Divergence**
# > At 04:12 am, Lieutenant Marin’s dispatch was delivered directly to the left‑flank artillery commander, Major Kovács, as originally intended. The order to commence the preparatory barrage was therefore obeyed without delay.
# >
# > **B. Immediate Ripple**
# > At 04:15 am the left‑flank batteries unleashed a three‑minute, 120‑mm shrapnel barrage that broke the enemy’s forward skirmish line and forced their cavalry to dismount. The smoke and concussion also masked the infantry’s movement across the adjacent ridge.
# >
# > **C. Mid‑Battle Cascade**
# > 1. **Infantry Hold** – Because the enemy’s approach was blunted, the 2nd Infantry Regiment held the hilltop with only 5 % casualties, instead of the 30 % it suffered in the original account.
# > 2. **Command Confidence** – General Armand, witnessing the successful artillery‑infantry coordination, refrained from issuing a retreat order and instead ordered a limited counter‑attack on the enemy’s right flank.
# > 3. **Enemy Disarray** – The enemy, expecting a weakened defense, found its own right flank exposed and began to withdraw in a disorganized fashion.
# >
# > **D. End‑State Outcome**
# > By 07:30 am the opposing army had pulled back across the river, abandoning its supply wagons. The victory cemented the victorious commander’s control over the province, leading to a peace treaty three months later that preserved the pre‑war borders. The long‑term political map of the region remained largely unchanged, avoiding the cascade of wars that, in our known history, erupted after the original defeat.
# >
# > **E. Probability Reflection**
# > Contemporary military dispatches in the era were delivered by a relay of mounted couriers with a documented success rate of ≈92 %. Given clear weather and a well‑trained courier corps, the likelihood of the correct delivery was high; the fictional interception by a stray scout is an outlier that dramatically lowered the odds of success in the original timeline. By restoring the most probable transmission path, the subsequent chain of events aligns with documented tactical doctrines of the period.
# >
# > **F. Limitations Disclaimer**
# > This reconstruction holds all other variables constant—troop morale, weather, terrain, and enemy leadership. In reality, any of those factors could have shifted the battle’s dynamics even with the correct artillery fire. Moreover, the narrative is built on a fictional source that invents characters and units; therefore, while the logical chain is internally consistent, it cannot be claimed as a definitive alternate history.
#
# ---
#
# ## 4.  Methodological Checklist for the LLM (or a human historian)
#
# | **Task** | **How to Execute** | **Typical Pitfall** |
# |----------|-------------------|----------------------|
# | **Extract PoD** | Locate the first sentence that describes the mis‑communication. Tag actors, message, channel, and timestamp. | Missing the *actual* intended receiver (often implied). |
# | **Map immediate tactical effect** | Ask: “What action was supposed to happen, and what actually happened?” | Assuming the missed action had *no* effect. |
# | **Chain forward** | For each node, ask: “Given X, what decision would a rational commander make?” | Over‑jumping steps; skipping intermediate decisions. |
# | **Assess plausibility** | Compare to known historical rates (messenger loss, mis‑read signals, battle‑field casualty norms). Use qualitative descriptors (“unlikely”, “reasonable”). | Using precise percentages without source backing. |
# | **Write the counter‑factual** | Follow the A‑F structure above; keep each link tight (one cause → one effect). | Adding extraneous “what‑ifs” that dilute the causal chain. |
# | **Add disclaimer** | Explicitly note assumptions (ceteris‑paribus, fictional characters, limited source). | Forgetting to qualify the speculative nature. |
#
# ---
#
# ## 5.  Why This Approach Works
#
# 1. **Causality First** – By isolating the *single* mis‑communication, we respect the user’s constraint that the divergence stems from one seed event.
# 2. **Chain‑by‑Chain Transparency** – A stepwise, numbered list makes the reasoning traceable, allowing readers (or reviewers) to see where the story could be contested.
# 3. **Probability Language** – Even in a fictional setting we can borrow real‑world statistical norms (messenger reliability, battle attrition rates) to give the chain a sense of realism without pretending to have exact data.
# 4. **Counter‑factual Structure** – The A‑F template mirrors classic historiographical “what‑if” essays, making the final narrative feel scholarly while staying imaginative.
# 5. **Explicit Limits** – The final disclaimer acknowledges that any chain we construct is an *interpretive model*, not an empirical truth—exactly what responsible counter‑factual work requires.
#
# ---
#
# ### TL;DR (Bottom‑Line Summary)
#
# 1. **Identify** the mis‑communication: who said what, who heard it, when, and via which channel.
# 2. **Diagram** the cascading effects, rating each link’s improbability against known historical baselines.
# 3. **Write** a counter‑factual narrative that (a) restores the intended message, (b) follows the logical ripple‑effects step‑by‑step, (c) ends with a plausible alternate outcome, and (d) ends with a clear disclaimer of the speculative nature.
#
# Using this systematic, evidence‑aware yet imaginative workflow, an LLM can turn a “single minor mis‑communication” in a fictional battle into a rigorously argued, plausible alternate history while remaining transparent about the limits of what can ever be proven in a wholly invented scenario.

# %%
competitors
# Out:
# ['openai/gpt-oss-120b',
#  'mistralai/Mistral-7B-Instruct-v0.2',
#  'mistralai/Mistral-7B-Instruct-v0.2',
#  'meta-llama/llama-3.1-8b-instruct',
#  'gemini-2.5-flash',
#  'openai/gpt-oss-120b']

# %%
answers
# Out:
# ["Below is a step‑by‑step blueprint you can follow (and adapt to the specific battle you have in mind) that shows **how** an LLM can:\n\n1. **extract the “divergence point” and the cascade it triggers,**  \n2. **lay out the causal chain in a clear, historically‑informed way,**  \n3. **turn that chain into a coherent counter‑factual narrative,** and  \n4. **explicitly flag the epistemic limits that any fictional‑history exercise carries.**  \n\n---\n\n## 1. Ground‑Truth Baseline – What *actually* happened?\n\nBefore you can spot the “what‑if” you need a concise picture of the accepted history:\n\n| Element | Typical Historical Account |\n|---------|----------------------------|\n| **Belligerents** | *Side\u202fA* (conventionally victorious) vs. *Side\u202fB* |\n| **Strategic Objective** | *Side\u202fA* wanted X; *Side\u202fB* wanted Y |\n| **Key Decision‑Points** | 1. Order to advance on hill 2. Timing of cavalry charge 3. Logistics of supply |\n| **Outcome** | *Side\u202fA* wins, securing Z (political, territorial, etc.) |\n| **Probabilistic Rating** (subjective) | 70‑90\u202f% chance of *Side\u202fA* victory (based on primary sources, logistics, morale, etc.) |\n\n*Why do this?*  \nIt supplies the “control” against which every branch of the counter‑factual can be measured and it lets you state, “All else being equal, the battle was highly likely to end this way.”\n\n---\n\n## 2. Locate the **Single Miscommunication** that Seeds the Divergence\n\n### 2.1. Pinpoint the Exact Message\n\n| Feature | Typical Historical Record | Fictional Mis‑communication |\n|---------|---------------------------|-----------------------------|\n| **Sender** | Commander\u202fX (e.g., corps commander) | Same |\n| **Recipient** | Brigade\u202fY (e.g., infantry unit) | Same |\n| **Medium** | Courier on horseback | Same |\n| **Content (historical)** | “Hold position until 0600\u202fh, then advance on the ridge.” | “Hold position until 0600\u202fh, then **withdraw** from the ridge.” |\n| **Timing** | Delivered 30\u202fmin before the deadline | Delivered 5\u202fmin after the deadline (so troops already engaged) |\n| **Source of Error** | Scribal slip (“adv**a**nce” vs “with**d**raw”) | Same |\n\n### 2.2. Why this is the *only* plausible fork\n\n* **No other contemporaneous orders contradict it.** All other dispatches are internally consistent.\n* **Logistical constraints make a rapid correction impossible.** The nearest messenger is already deep in enemy fire.\n* **Human factors** (fatigue, poor visibility) raise the probability that the error is *not* noticed until after execution.\n\n---\n\n## 3. Build the **Causal Chain** – From Mis‑message to Battle‑wide Collapse\n\nA causal chain can be visualized as a directed acyclic graph (DAG). Below is a textual “flowchart” that an LLM can generate, with each arrow annotated by a *probability modifier* (how much the step makes the original outcome more/less likely).\n\n```\n[Mis‑communication] ──► [Brigade Y withdraws from ridge] (‑30\u202f% chance of holding line)\n          │\n          ▼\n[Gap opens in the centre] ──► [Enemy artillery concentrates fire on the gap] (‑20\u202f% morale for adjacent units)\n          │\n          ▼\n[Adjacent Brigade Z hesitates, mis‑reads retreat as defeat] (‑15\u202f% cohesion)\n          │\n          ▼\n[Commander's reserve, slated for a flanking maneuver, is redirected to plug the gap] (‑10\u202f% ability to execute original plan)\n          │\n          ▼\n[Original decisive cavalry charge is delayed 20\u202fmin] (‑25\u202f% chance of breaking enemy line)\n          │\n          ▼\n[Enemy commander seizes the initiative, orders a counter‑attack] (↑15\u202f% chance of enemy breakthrough)\n          │\n          ▼\n[Side\u202fA's line collapses → Battle lost] (Overall shift: from +70\u202f% to −40\u202f% chance of victory)\n```\n\n**How to articulate each link**  \n\n1. **State the event** (e.g., “Brigade\u202fY pulled back”).  \n2. **Reference the underlying mechanism** (ter ...
#  ' As a legal scholar and not a historian, I will approach this question with a focus on identifying and analyzing the potential legal implications and causal chains arising from the hypothetical miscommunication in the given fictional historical account. I will then construct a counterfactual narrative based on the identified causal links.\n\nIdentification of Causal Chain:\nLet us assume the fictional historical account centers around the Battle of Waterloo in 1815, but with a minor deviation - a vital French command communication intended for Napolean Bonaparte was intercepted and misunderstood by Marshal Ney, who consequently mispositioned the French forces. Instead of a decisive victory for the French, the battle resulted in a loss.\n\n1. Miscommunication: The French command communication, meant for Bonaparte, was intercepted by the British forces (possibly due to a double agent or an mistake in cipher).',
#  ' To identify and articulate the causal chain of the divergence from historical probability in a fictional historical account where a pivotal battle was not won by the conventionally understood victor due to a single, seemingly minor, miscommunication, I would follow these steps:\n\n1. Identify the miscommunication: The first step would be to identify the exact miscommunication that set off the chain of improbable events. This could involve analyzing the dialogue or actions of the key figures involved in the narrative leading up to the battle, and examining the potential meaning and intent behind their words or actions.\n\n2. Trace the immediate consequences: Once the miscommunication has been identified, the next step would be to trace the immediate consequences of that miscommunication. This could involve analyzing the actions of the opposing side, as well as their reactions to the perceived advantage gained due to the miscommunication.\n\n3. Consider the snowball effect: It is important to consider the potential snowball effect of the miscommunication, as the consequences can often compound over time, leading to even more significant and unforeseen outcomes. For example, a misunderstanding between two commanders could lead to a misdeployment of troops, which in turn could lead to a break in the enemy lines, which could lead to a panic among the enemy ranks, and so on.\n\n4. Consider the counterfactual: To construct a plausible, well-reasoned counterfactual narrative, it is essential to consider what would have happened if the miscommunication had not occurred. This could involve examining the strategic situation before the battle, as well as the motivations, capabilities, and dispositions of the key actors involved. It may also be necessary to make some assumptions about how events would have unfolded differently if the miscommunication had not taken place.\n\n5. Acknowledge the inherent limitations: It is important to acknowledge the inherent limitations in definitively establishing a causal chain in a fictional historical account. While analysis and reasoning can help shed light on the possible consequences of the miscommunication, it is ultimately impossible to know for sure how events would have unfolded if history had taken a different course. Therefore, any counterfactual narrative should be considered as a plausible, but not definitive, alternative to the conventional historical account.\n\n6. Use historical context: To make the counterfactual narrative more compelling, it is essential to ground it in historical context. This could involve using real historical facts and events as a basis for the narrative and extrapolating from them in a plausible way. For example, if the miscommunication occurred during the Battle of Waterloo, it could be useful to consider the strategic situation on the ground, the dispositions of the armies, and the motivations of the key commanders involved.\n\n7. Use logical reasoning: To craft a convincing counterfactual narrative, it is important to use logical reasoning to explain why and how the miscommunication led to the divergence from historical probability. This could involve examining the potential motivations and rationales of the key actors involved, as well as the strategic and tactical implications of their actions and reactions. Logical reasoning can help to establish a coherent and plausible narrative that challenges the conventional historical account.\n\n8. Consider the ripple effects: To create a fully developed counterfactual narrative, it is important to consider the ripple effects of the miscommunication and the potential ways in which the divergence from historical probability could have cascaded through history. For example, if a battle was not won by the conventionally understood victor, the aftermath could have significant consequences for the course of history. It may be necessary to consider the potential political, social, and economic implications of the alternati ...
#  ' To identify and articulate the causal chain of the divergence from historical probability in a fictional historical account where a pivotal battle was not won by the conventionally understood victor due to a single, seemingly minor, miscommunication, I would follow these steps:\n\n1. Identify the miscommunication: The first step would be to identify the exact miscommunication that set off the chain of improbable events. This could involve analyzing the dialogue or actions of the key figures involved in the narrative leading up to the battle, and examining the potential meaning and intent behind their words or actions.\n\n2. Trace the immediate consequences: Once the miscommunication has been identified, the next step would be to trace the immediate consequences of that miscommunication. This could involve analyzing the actions of the opposing side, as well as their reactions to the perceived advantage gained due to the miscommunication.\n\n3. Consider the snowball effect: It is important to consider the potential snowball effect of the miscommunication, as the consequences can often compound over time, leading to even more significant and unforeseen outcomes. For example, a misunderstanding between two commanders could lead to a misdeployment of troops, which in turn could lead to a break in the enemy lines, which could lead to a panic among the enemy ranks, and so on.\n\n4. Consider the counterfactual: To construct a plausible, well-reasoned counterfactual narrative, it is essential to consider what would have happened if the miscommunication had not occurred. This could involve examining the strategic situation before the battle, as well as the motivations, capabilities, and dispositions of the key actors involved. It may also be necessary to make some assumptions about how events would have unfolded differently if the miscommunication had not taken place.\n\n5. Acknowledge the inherent limitations: It is important to acknowledge the inherent limitations in definitively establishing a causal chain in a fictional historical account. While analysis and reasoning can help shed light on the possible consequences of the miscommunication, it is ultimately impossible to know for sure how events would have unfolded if history had taken a different course. Therefore, any counterfactual narrative should be considered as a plausible, but not definitive, alternative to the conventional historical account.\n\n6. Use historical context: To make the counterfactual narrative more compelling, it is essential to ground it in historical context. This could involve using real historical facts and events as a basis for the narrative and extrapolating from them in a plausible way. For example, if the miscommunication occurred during the Battle of Waterloo, it could be useful to consider the strategic situation on the ground, the dispositions of the armies, and the motivations of the key commanders involved.\n\n7. Use logical reasoning: To craft a convincing counterfactual narrative, it is important to use logical reasoning to explain why and how the miscommunication led to the divergence from historical probability. This could involve examining the potential motivations and rationales of the key actors involved, as well as the strategic and tactical implications of their actions and reactions. Logical reasoning can help to establish a coherent and plausible narrative that challenges the conventional historical account.\n\n8. Consider the ripple effects: To create a fully developed counterfactual narrative, it is important to consider the ripple effects of the miscommunication and the potential ways in which the divergence from historical probability could have cascaded through history. For example, if a battle was not won by the conventionally understood victor, the aftermath could have significant consequences for the course of history. It may be necessary to consider the potential political, social, and economic implications of the alternati ...
#  'This is an excellent challenge that delves into the core of counterfactual history and causal analysis, even within a fictional framework. As an LLM, my approach would involve a structured process of hypothesizing the initial conditions, tracing the logical (and improbable) consequences, and then reconstructing the "actual" timeline.\n\nLet\'s establish a fictional scenario first, to provide the ground for our analysis:\n\n---\n\n### **Fictional Scenario: The Battle of the Sunder Pass**\n\n**Conventional Understanding:** The Battle of the Sunder Pass (circa 17th century analogue) was historically understood to be a decisive victory for the **Coalition of Free Cities**, led by the brilliant tactician Lord-General Atherton. His masterful encirclement maneuver, combining a frontal assault with a hidden flank attack, was supposed to crush the entrenched **Imperial Hegemony** forces, led by the steadfast but less imaginative Marshal Kaelen. This victory was meant to open the way to the Imperial capital and hasten the end of a long war.\n\n**The Divergence (The Actual Outcome in this Fictional Account):** Contrary to the conventional understanding, the Coalition *lost* the Battle of the Sunder Pass catastrophically. Lord-General Atherton\'s forces were not only repulsed but suffered a devastating rout, allowing Marshal Kaelen to consolidate his position and prolong the war for several more years.\n\n---\n\n### **1. Identifying and Articulating the Causal Chain of Divergence**\n\nThe prompt states this divergence stems from a "single, seemingly minor, miscommunication" leading to "a series of cascading improbable events."\n\n**The Single, Seemingly Minor Miscommunication:**\n\n*   **The Message:** Lord-General Atherton\'s battle plan relied heavily on a synchronized pincer movement. His main infantry force would engage Marshal Kaelen\'s entrenched center, while a crucial cavalry division, commanded by General Valerius, would execute a wide flanking maneuver through the treacherous "Whispering Glade" to strike the Imperial rear.\n*   **The Critical Detail:** The precise time for Valerius\'s flank attack was paramount. Atherton\'s dispatch specified: "Valerius to initiate rear assault at *0600 hours*, coinciding with our main push. *Maintain radio silence until contact*."\n*   **The Miscommunication:** The courier carrying this vital dispatch to General Valerius was a junior officer, newly assigned and overly zealous. During the arduous night ride through rough terrain, he lost the top page of the two-page order. The second page, which detailed the *route* through the Glade, began with the instruction "Proceed *swiftly and silently until dawn*," followed by tactical details. The crucial "0600 hours" was on the missing first page. The young officer, having been ordered to deliver "the plan," presented only the surviving page, assuming it was complete. General Valerius, receiving only the second page, interpreted "Proceed swiftly and silently until dawn" as the *signal to begin his main advance* at first light, roughly 0500 hours, and *not* just a pre-movement instruction for the advance to its staging point. He also interpreted "Maintain radio silence until contact" as absolute, rather than just during the approach.\n\n**The Cascading Improbable Events (and their increasingly detrimental effects):**\n\n1.  **Event 1: Premature Flank Engagement (Direct Consequence of Miscommunication)**\n    *   **Link:** General Valerius, interpreting "until dawn" as the attack command, launched his cavalry attack an hour earlier than intended (around 0500 hours instead of 0600 hours).\n    *   **Impact:** This meant Valerius\'s cavalry hit the Imperial rear while Atherton\'s main frontal assault was still maneuvering into position, well before its coordinated 0600 push. The Imperial rear, though caught off guard, faced a comparatively smaller, isolated force.\n\n2.  **Event 2: Imperial Counter-Response and Early Warning (First Improbable Link)**\n    ...
#  'Below is a step‑by‑step guide that shows **how** an LLM can (1) pull the divergent thread out of a fictional “what‑if” scenario, (2) map the chain of cause‑and‑effect that turned the battle on its head, (3) turn that map into a coherent counter‑factual narrative, and (4) keep the analysis honest about the speculative nature of the exercise.  \n\n---\n\n## 1.  Unpacking the Premise – Pinpoint the “Single Mis‑communication”\n\n| **What to look for** | **Why it matters** | **Typical evidence (fictional or real)** |\n|----------------------|--------------------|------------------------------------------|\n| **Who said what, to whom, and when?** | A mis‑communication is only a *mis‑communication* if the message reached the wrong audience or arrived at the wrong time. | A messenger’s delayed report, a mis‑read signal flag, an ambiguous written order. |\n| **The medium of transmission** | Different media have distinct failure modes (e.g., smoke signals vs. written dispatch). | Smoke mis‑read as “retreat” instead of “hold”. |\n| **Contextual pressure** | High‑stress situations (night, rain, chaos) raise the probability of a slip. | Night‑time crossing of a river while under artillery fire. |\n| **Immediate decision made on the basis of the error** | This decision is the first node in the causal chain. | The commander decides to abandon a hilltop position. |\n\n**Action for the LLM:**  \n1. **Extract the sentence(s)** that describe the mis‑communication.  \n2. **Tag** the actors (sender, receiver), the *message* (content), and the *channel* (courier, signal, etc.).  \n3. **Timestamp** the event relative to the battle timeline (e.g., “30\u202fmin before the main assault”).  \n\n*Example (fictional):*  \n> “At 04:12\u202fam, Lieutenant\u202fMarin’s dispatch, intended to order the left‑flank artillery to fire a preparatory barrage, was intercepted by a stray scout and delivered to Captain Varga, who interpreted it as a command to withdraw the batteries.”\n\n- **Sender:** Lieutenant\u202fMarin  \n- **Receiver (intended):** Left‑flank artillery commander  \n- **Receiver (actual):** Captain Varga (infantry)  \n- **Message:** “Fire preparatory barrage” → mis‑read as “withdraw”\n\n---\n\n## 2.  Building the Causal Chain – From One Mistake to a Battle‑wide Collapse\n\n### 2.1  Diagrammatic Thinking (Narrative‑Friendly)\n\n```\nMis‑communication\n      ↓\nImmediate tactical error (artillery does not fire)\n      ↓\nEnemy retains momentum (no suppression)\n      ↓\nInfantry flank is exposed → higher casualties\n      ↓\nCommanding general loses confidence → orders premature retreat\n      ↓\nMorale collapses → units begin to rout\n      ↓\nEnemy exploits gap → decisive victory\n```\n\n### 2.2  Assessing “Improbability”\n\n| **Link** | **Historical baseline probability** | **Improbability factor** (qualitative) | **Why the fiction makes it plausible** |\n|----------|------------------------------------|----------------------------------------|----------------------------------------|\n| Artillery fails to fire because of mis‑read order | ~5\u202f% (messenger loss, mis‑read orders were rare) | **High** (requires both interception and misinterpretation) | The story adds a *stray scout* in a foggy night, raising the odds. |\n| Enemy retains momentum without artillery suppression | ~30\u202f% (depends on terrain, enemy discipline) | **Medium** | The hill‑top gave the enemy a line‑of‑sight advantage; losing barrage mattered. |\n| Premature retreat ordered by general | ~10\u202f% (generals rarely retreat early unless convinced) | **Medium‑High** | General is portrayed as already nervous after prior setbacks. |\n| Morale collapse → rout | ~15\u202f% (depends on cohesion, leadership) | **Medium** | The army had a mixed composition of conscripts and veterans; the loss of artillery was a psychological shock. |\n\n**LLM tip:** Use *qualitative* probability language (“unlikely but not impossible”) rather than precise numbers unless the source material suppl ...

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
